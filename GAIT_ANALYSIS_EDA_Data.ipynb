# %% [markdown]
# <a href="https://colab.research.google.com/github/shumshersubashgautam/KU-Research-Gait_Analysis/blob/main/GAIT_ANALYSIS_EDA_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -r /content/gdrive/MyDrive/gait-phase-detection-using-joing-angles-dataset /content/

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/gaitphase'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /content/gaitphase/gait-phase-detection-using-joint-angles-testing-dataset.xlsx
# /content/gaitphase/gait-phase-detection-using-joint-angles-training-dataset.xlsx
# /content/gaitphase/gait-phase-detection-using-joint-angles-testing-dataset.csv
# /content/gaitphase/gait-phase-detection-using-joint-angles-training-dataset.csv

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
data = '/content/gaitphase/gait-phase-detection-using-joint-angles-training-dataset.csv'

df = pd.read_csv(data)

# %%
df.shape
# Out:
# (4373, 4)

# %%
df.head()
# Out:
#    hip-angle  knee-angle  ankle-angle  phase
# 0  19.033295    2.793752    66.436670      1
# 1  20.733910    3.179830    67.298731      1
# 2  21.417248    3.179830    67.298731      1
# 3  22.349802    3.881837    68.013458      1
# 4  23.864921    5.276593    67.878058      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4373 entries, 0 to 4372
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hip-angle    4373 non-null   float64
#  1   knee-angle   4373 non-null   float64
#  2   ankle-angle  4373 non-null   float64
#  3   phase        4373 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 136.8 KB

# %%
df.isnull().sum()
# Out:
# hip-angle      0
# knee-angle     0
# ankle-angle    0
# phase          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4373 entries, 0 to 4372
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hip-angle    4373 non-null   float64
#  1   knee-angle   4373 non-null   float64
#  2   ankle-angle  4373 non-null   float64
#  3   phase        4373 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 136.8 KB

# %%
df.describe()
# Out:
#          hip-angle   knee-angle  ankle-angle        phase
# count  4373.000000  4373.000000  4373.000000  4373.000000
# mean     11.196905    12.629076    72.854762     0.921107
# std       9.098236    11.728601     9.676415     0.269603
# min       0.004842     0.000000     0.666200     0.000000
# 25%       2.724839     3.301705    67.047841     1.000000
# 50%       8.358669     7.392635    73.310748     1.000000
# 75%      19.479664    21.320152    79.666747     1.000000
# max      34.208483    54.293097   100.406856     1.000000

# %%
# view the labels in the variable

df['hip-angle'].unique()
# Out:
# array([19.03329524, 20.7339098 , 21.41724814, ..., 10.15675734,
#        10.04961735,  9.94675251])

# %%
# view how many different types of variables are there

len(df['hip-angle'].unique())
# Out:
# 3964

# %%
# view the labels in the variable

df['knee-angle'].unique()
# Out:
# array([ 2.79375195,  3.17983012,  3.88183728, ..., 23.04632896,
#        22.89170922, 23.25410966])

# %%
# view how many different types of variables are there

len(df['knee-angle'].unique())
# Out:
# 3719

# %%
# view the labels in the variable

df['ankle-angle'].unique()
# Out:
# array([66.43667003, 67.2987308 , 68.01345783, ..., 78.55895613,
#        79.063319  , 79.32285459])

# %%
# view how many different types of variables are there

len(df['ankle-angle'].unique())
# Out:
# 3570

# %%
df.head()
# Out:
#    hip-angle  knee-angle  ankle-angle  phase
# 0  19.033295    2.793752    66.436670      1
# 1  20.733910    3.179830    67.298731      1
# 2  21.417248    3.179830    67.298731      1
# 3  22.349802    3.881837    68.013458      1
# 4  23.864921    5.276593    67.878058      1

# %%
X = df

y = df['phase']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

X['knee-angle'] = le.fit_transform(X['knee-angle'])

y = le.transform(y)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4373 entries, 0 to 4372
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hip-angle    4373 non-null   float64
#  1   knee-angle   4373 non-null   int64
#  2   ankle-angle  4373 non-null   float64
#  3   phase        4373 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 136.8 KB

# %%
X.head()
# Out:
#    hip-angle  knee-angle  ankle-angle  phase
# 0  19.033295         695    66.436670      1
# 1  20.733910         802    67.298731      1
# 2  21.417248         802    67.298731      1
# 3  22.349802        1009    68.013458      1
# 4  23.864921        1348    67.878058      1

# %%
cols = X.columns

# %%
from sklearn.preprocessing import MinMaxScaler

ms = MinMaxScaler()

X = ms.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=[cols])

# %%
X.head()
# Out:
#   hip-angle knee-angle ankle-angle phase
# 0  0.556328   0.186928    0.659415   1.0
# 1  0.606049   0.215707    0.668058   1.0
# 2  0.626027   0.215707    0.668058   1.0
# 3  0.653292   0.271382    0.675224   1.0
# 4  0.697589   0.362561    0.673866   1.0

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0) 

kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 5.89677399e-01,  7.95299015e-01,  6.80016916e-01,
#         -2.66453526e-15],
#        [ 3.04738739e-01,  4.48799033e-01,  7.27509506e-01,
#          1.00000000e+00]])

# %%
kmeans.inertia_
# Out:
# 648.4477309749434

# %%
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
# Out:
# Result: 4373 out of 4373 samples were correctly labeled.

# %%
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Accuracy score: 1.00

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2,random_state=0)

kmeans.fit(X)

labels = kmeans.labels_

# check how many of the samples were correctly labeled

correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))

print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 4373 out of 4373 samples were correctly labeled.
# Accuracy score: 1.00

# %%
kmeans = KMeans(n_clusters=3, random_state=0)

kmeans.fit(X)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 2557 out of 4373 samples were correctly labeled.
# Accuracy score: 0.58

# %%
kmeans = KMeans(n_clusters=4, random_state=0)

kmeans.fit(X)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 1460 out of 4373 samples were correctly labeled.
# Accuracy score: 0.33

# %%
#importing usefull lib

import numpy as np
import pandas as pd
import seaborn as sns
import warnings as wr
wr.filterwarnings("ignore")
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#reading the data using pandas read_csv. 
#It's ofthen used pandas fuction to read csc file.
import pandas as pd
df1=pd.read_csv("/content/gaitphase/gait-phase-detection-using-joint-angles-training-dataset.csv")
df1.head()
# Out:
#    hip-angle  knee-angle  ankle-angle  phase
# 0  19.033295    2.793752    66.436670      1
# 1  20.733910    3.179830    67.298731      1
# 2  21.417248    3.179830    67.298731      1
# 3  22.349802    3.881837    68.013458      1
# 4  23.864921    5.276593    67.878058      1

# %%
#checking shape of data frame
df1.shape
# Out:
# (4373, 4)

# %%
#here we check mean,std,quantiles value using pandas describe function
df1.describe()
# Out:
#          hip-angle   knee-angle  ankle-angle        phase
# count  4373.000000  4373.000000  4373.000000  4373.000000
# mean     11.196905    12.629076    72.854762     0.921107
# std       9.098236    11.728601     9.676415     0.269603
# min       0.004842     0.000000     0.666200     0.000000
# 25%       2.724839     3.301705    67.047841     1.000000
# 50%       8.358669     7.392635    73.310748     1.000000
# 75%      19.479664    21.320152    79.666747     1.000000
# max      34.208483    54.293097   100.406856     1.000000

# %%
#extracting all columns from the data frame for forother uses
df1.columns.tolist()
# Out:
# ['hip-angle', 'knee-angle', 'ankle-angle', 'phase']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4373 entries, 0 to 4372
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hip-angle    4373 non-null   float64
#  1   knee-angle   4373 non-null   int64
#  2   ankle-angle  4373 non-null   float64
#  3   phase        4373 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 136.8 KB

# %%
print(f'Number of steps on floor  as 0 are {df.phase.value_counts()[0]} and Number of phase on swing as 1 are {df.phase.value_counts()[1]}')
sns.countplot(df["phase"])
plt.show()
# Out:
# Number of steps on floor  as 0 are 345 and Number of phase on swing as 1 are 4028

# %%
#here wr checking outliers 
f,ax=plt.subplots()
sns.violinplot(data=df.iloc[:,0:4])
sns.despine(offset=10,trim=True)

# %%
#here we going to ploat scaterplot to see data distirbution
sns.relplot(x="hip-angle",y="knee-angle",hue="ankle-angle",data=df);

# %%
#here we going to ploat scaterplot to see data distirbution
sns.relplot(x="knee-angle",y="ankle-angle",hue="phase",data=df);

# %%
#visualisation how many pasanger survived and how many dead
#here we creat a function for bar_chart 
#for avoiding write same code for defrent columns

def bar_chart(column):
    survived=df[df["phase"]==1][column].value_counts()
    dead=df[df["phase"]==0][column].value_counts()
    df1=pd.DataFrame([survived,dead])
    df1.index=["Step-Floor","Step-Swing"]
    df1.plot(kind="bar",figsize=(10,5))

# %%
#here we make a bar chart on sex column
#for checking how many male & female
bar_chart("phase")

# %%
#visualisation data on boxplot to see the outliers
def box_plot(column):
    df.boxplot(by="phase",column=[column],grid=True)

# %%
box_plot("hip-angle")

# %%
#checking outliers on Sibsp column
box_plot("knee-angle")

# %%
#checking outliers on Sibsp column
box_plot("ankle-angle")

# %%
#ploting pair plot
g=sns.PairGrid(df,hue="phase")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend
# Out:
# <bound method Grid.add_legend of <seaborn.axisgrid.PairGrid object at 0x7f32b06f5ee0>>

# %%
#by value_counts we can see total unique values
df["hip-angle"].value_counts()
# Out:
# 8.133623     9
# 17.130393    9
# 0.788864     6
# 2.579147     6
# 0.573427     6
#             ..
# 17.583909    1
# 17.133337    1
# 17.942850    1
# 19.537841    1
# 9.946753     1
# Name: hip-angle, Length: 3964, dtype: int64

# %%
#here we chacking largest values row on column Sibsp
df.nlargest(12,["hip-angle"])
# Out:
#       hip-angle  knee-angle  ankle-angle  phase
# 3075  34.208483        2807    71.110683      0
# 3432  34.020943        2348    64.206924      0
# 3011  33.244703        3470    78.290999      0
# 4047  32.967077        2760    76.149507      1
# 3076  32.929449        2774    71.804781      1
# 4045  32.795767        2921    74.930239      1
# 4043  32.795437        2650    73.590561      1
# 4044  32.787846        2736    76.484268      1
# 2906  32.639025        2473    66.777341      1
# 2905  32.302131        2387    66.463138      0
# 4046  32.198788        2854    76.551385      1
# 3433  32.025099        2521    66.614779      1

# %%
df.nlargest(12,["knee-angle"])
# Out:
#       hip-angle  knee-angle  ankle-angle  phase
# 535   14.652231        3718    58.701184      0
# 433    8.810068        3717    69.208219      0
# 3180  21.009208        3716    65.965294      0
# 534   11.098721        3715    66.077494      1
# 1044  15.400587        3714    56.346033      0
# 921   12.290677        3713    61.390122      0
# 3088  18.798252        3712    62.622297      0
# 2836  26.064088        3711    82.667531      0
# 72     9.390550        3710    67.996944      1
# 3105  21.278742        3709    71.402007      0
# 329   14.409859        3708    65.285464      0
# 536   18.397764        3707    66.806846      0

# %%
#here we going to drow heatmap to check co relation between columns 

plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %%
#droping an relevant columns
#dividing data X(features) and Y(outcome)
X=df["knee-angle"]
y=df["phase"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (4373,)
# (4373,)
